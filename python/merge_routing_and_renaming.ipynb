# %% [markdown]
# # Merge renaming file and routing file
#
# This code merges the a table containing information about routing in questions into the larger data description table. Each wave gets it's own routing column.

# %%
import pandas as pd

# %%
# Load tables
renaming = pd.read_csv("tables/xyx-corona-questionnaire_renaming.csv", sep=";")
routing = pd.read_csv("tables/routing_table.csv", sep=";")

# %%
wave_columns = ["L_CoronavirusImpact_wave3_4p.dta", "L_CoronavirusImpact_4.0p.dta","L_CoronavirusImpact_3p.dta"]

# %%
for i, wave in enumerate(wave_columns):
    w = routing.loc[routing["wave"]==i+1]
    w = w.rename(columns={"routing":f"routing_wave_{i+1}"})
    renaming = renaming.merge(w[["original_name", f"routing_wave_{i+1}"]], 
                           how="left", 
                           left_on=wave, 
                           right_on="original_name")
    renaming.drop("original_name", axis=1,inplace=True)

# %%
renaming.to_csv("tables/xyx-corona-questionnaire_renaming_including_routing.csv", sep=";",index=False)

# %%
renaming
# Out:
#                          new_name  reference period other than survey period  \
# 0                   l_2m_infected                                        NaN
# 1      l_2m_acquaintance_infected                                        NaN
# 2    l_2m_hospital_if_infect_self                                        NaN
# 3                 l_2m_quarantine                                        NaN
# 4       l_2m_infected_and_pass_on                                        NaN
# ..                            ...                                        ...
# 934   teacher_platform_sec_child5                                        NaN
# 935     teacher_pickup_sec_child5                                        NaN
# 936       teacher_none_sec_child5                                        NaN
# 937      teacher_other_sec_child5                                        NaN
# 938  teacher_other_sec_child5_str                                        NaN
#
#                                          label_english  \
# 0    How likely do you think it is that you will be...
# 1    How likely do you think it is that someone in ...
# 2    How likely do you think it is that you will ne...
# 3    How likely do you think it is that you will be...
# 4    How likely do you think it is that you will ge...
# ..                                                 ...
# 934  Teacher(s) and pupil/parents communicated and ...
# 935   Teaching materials had to be picked up at school
# 936  There was no communication between teacher(s) ...
# 937     Another way of communication/exchange, namely:
# 938     Another way of communication/exchange, namely:
#
#     L_CoronavirusImpact_wave3_4p.dta L_CoronavirusImpact_4.0p.dta  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
# ..                               ...                          ...
# 934                    v6_vokind5__5                          NaN
# 935                    v6_vokind5__6                          NaN
# 936                    v6_vokind5__7                          NaN
# 937                    v6_vokind5__8                          NaN
# 938                   v6_and_vokind5                          NaN
#
#     L_CoronavirusImpact_3p.dta         type  \
# 0                          q1a  Categorical
# 1                          q1b  Categorical
# 2                          q1c  Categorical
# 3                          q1d  Categorical
# 4                          q1e  Categorical
# ..                         ...          ...
# 934                        NaN         bool
# 935                        NaN         bool
# 936                        NaN         bool
# 937                        NaN         bool
# 938                        NaN          str
#
#                                     categories_english ordered  \
# 0    not at all likely, very unlikely, rather unlik...    True
# 1    not at all likely, very unlikely, rather unlik...    True
# 2    not at all likely, very unlikely, rather unlik...    True
# 3    not at all likely, very unlikely, rather unlik...    True
# 4    not at all likely, very unlikely, rather unlik...    True
# ..                                                 ...     ...
# 934                                                NaN     NaN
# 935                                                NaN     NaN
# 936                                                NaN     NaN
# 937                                                NaN     NaN
# 938                                                NaN     NaN
#
#       topic_english question_group routing_wave_1 routing_wave_2  \
# 0    Health Beliefs             q1            NaN            NaN
# 1    Health Beliefs             q1            NaN            NaN
# 2    Health Beliefs             q1            NaN            NaN
# 3    Health Beliefs             q1            NaN            NaN
# 4    Health Beliefs             q1            NaN            NaN
# ..              ...            ...            ...            ...
# 934       Childcare      v6_bokind            NaN            NaN
# 935       Childcare      v6_bokind            NaN            NaN
# 936       Childcare      v6_bokind            NaN            NaN
# 937       Childcare      v6_bokind            NaN            NaN
# 938       Childcare      v6_bokind            NaN            NaN
#
#     routing_wave_3
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 934            NaN
# 935            NaN
# 936            NaN
# 937            NaN
# 938            NaN
#
# [939 rows x 14 columns]
