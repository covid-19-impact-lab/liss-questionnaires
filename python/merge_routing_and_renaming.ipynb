# %% [markdown]
# # Merge renaming file and routing file
#
# This code merges the a table containing information about routing in questions into the larger data description table. Each wave gets it's own routing column.

# %%
import pandas as pd

# %%
# Load tables
renaming = pd.read_csv("tables/xyx-corona-questionnaire_renaming.csv", sep=";")
routing = pd.read_csv("tables/old/routing_table.csv", sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e4f6d08f3c0a> in <module>
#       1 # Load tables
#       2 renaming = pd.read_csv("tables/xyx-corona-questionnaire_renaming.csv", sep=";")
# ----> 3 routing = pd.read_csv("tables/old/routing_table.csv", sep=";")
#
# ~/miniconda3/envs/liss-data/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/miniconda3/envs/liss-data/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/miniconda3/envs/liss-data/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/miniconda3/envs/liss-data/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/miniconda3/envs/liss-data/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File tables/old/routing_table.csv does not exist: 'tables/old/routing_table.csv'

# %%
wave_columns = ["L_CoronavirusImpact_wave4_4p.dta", "L_CoronavirusImpact_wave3_4p.dta", "L_CoronavirusImpact_4.0p.dta","L_CoronavirusImpact_3p.dta"]

# %%
for i, wave in enumerate(wave_columns):
    w = routing.loc[routing["wave"]==i+1]
    w = w.rename(columns={"routing":f"routing_wave_{i+1}"})
    renaming = renaming.merge(w[["original_name", f"routing_wave_{i+1}"]], 
                           how="left", 
                           left_on=wave, 
                           right_on="original_name")
    renaming.drop("original_name", axis=1,inplace=True)

# %%
renaming.to_csv("tables/xyx-corona-questionnaire_renaming_including_routing.csv", sep=";",index=False)

# %%
renaming
# Out:
#                             new_name  \
# 0                      l_2m_infected
# 1         l_2m_acquaintance_infected
# 2       l_2m_hospital_if_infect_self
# 3                    l_2m_quarantine
# 4          l_2m_infected_and_pass_on
# ...                              ...
# 1319  no_school_infect_hh_sec_child5
# 1320     no_school_exempt_sec_child5
# 1321  no_school_household_sec_child5
# 1322      no_school_other_sec_child5
# 1323  no_school_other_str_sec_child5
#
#      reference period other than survey period  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1319                                       NaN
# 1320                                       NaN
# 1321                                       NaN
# 1322                                       NaN
# 1323                                       NaN
#
#                                           label_english  \
# 0     How likely do you think it is that you will be...
# 1     How likely do you think it is that someone in ...
# 2     How likely do you think it is that you will ne...
# 3     How likely do you think it is that you will be...
# 4     How likely do you think it is that you will ge...
# ...                                                 ...
# 1319                                                NaN
# 1320                                                NaN
# 1321                                                NaN
# 1322                                                NaN
# 1323                                                NaN
#
#      L_CoronavirusImpact_wave4_4p.dta L_CoronavirusImpact_wave3_4p.dta  \
# 0                                 NaN                              NaN
# 1                                 NaN                              NaN
# 2                                 NaN                              NaN
# 3                                 NaN                              NaN
# 4                                 NaN                              NaN
# ...                               ...                              ...
# 1319                    v3_vokind5__3                              NaN
# 1320                    v3_vokind5__4                              NaN
# 1321                    v3_vokind5__5                              NaN
# 1322                    v3_vokind5__6                              NaN
# 1323                    v3and_vokind5                              NaN
#
#      L_CoronavirusImpact_4.0p.dta L_CoronavirusImpact_3p.dta         type  \
# 0                             NaN                        q1a  Categorical
# 1                             NaN                        q1b  Categorical
# 2                             NaN                        q1c  Categorical
# 3                             NaN                        q1d  Categorical
# 4                             NaN                        q1e  Categorical
# ...                           ...                        ...          ...
# 1319                          NaN                        NaN         bool
# 1320                          NaN                        NaN         bool
# 1321                          NaN                        NaN         bool
# 1322                          NaN                        NaN         bool
# 1323                          NaN                        NaN  Categorical
#
#                                      categories_english ordered  \
# 0     not at all likely, very unlikely, rather unlik...    True
# 1     not at all likely, very unlikely, rather unlik...    True
# 2     not at all likely, very unlikely, rather unlik...    True
# 3     not at all likely, very unlikely, rather unlik...    True
# 4     not at all likely, very unlikely, rather unlik...    True
# ...                                                 ...     ...
# 1319                                                NaN     NaN
# 1320                                                NaN     NaN
# 1321                                                NaN     NaN
# 1322                                                NaN     NaN
# 1323                                                NaN     NaN
#
#        topic_english question_group routing_wave_1 routing_wave_2  \
# 0     Health Beliefs             q1            NaN            NaN
# 1     Health Beliefs             q1            NaN            NaN
# 2     Health Beliefs             q1            NaN            NaN
# 3     Health Beliefs             q1            NaN            NaN
# 4     Health Beliefs             q1            NaN            NaN
# ...              ...            ...            ...            ...
# 1319       Childcare      v3_vokind            NaN            NaN
# 1320       Childcare      v3_vokind            NaN            NaN
# 1321       Childcare      v3_vokind            NaN            NaN
# 1322       Childcare      v3_vokind            NaN            NaN
# 1323       Childcare      v3_vokind            NaN            NaN
#
#      routing_wave_3 routing_wave_4
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN
# ...             ...            ...
# 1319            NaN            NaN
# 1320            NaN            NaN
# 1321            NaN            NaN
# 1322            NaN            NaN
# 1323            NaN            NaN
#
# [1324 rows x 16 columns]
